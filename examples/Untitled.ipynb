# %%
import numpy as np
from PIL import Image

# %%
# %cd ..
# Out:
# /home/michal/workspace/gsplat
# /home/michal/anaconda3/envs/gsplat/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
img = Image.open("images/checker.jpeg")
mask_img = Image.open("images/checker_masked.jpeg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
mask_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
img_arr = np.array(img)
img_background = np.ones_like(img_arr)
mask_img_arr = np.array(mask_img)
mask_img_arr = mask_img_arr[:,:,:1].reshape(mask_img_arr.shape[0], mask_img_arr.shape[1]) #256, 256, 1
mask = np.where(mask_img_arr==[255], True, False)

# %%
img_arr[mask] = np.array([255])
Image.fromarray(img_arr)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
